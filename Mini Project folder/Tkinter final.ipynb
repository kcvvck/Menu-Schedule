# %%
from tkinter import *
from PIL import Image, ImageTk  #for image of map
import time
from datetime import datetime, date
import numpy as np
import cv2
from matplotlib import pyplot as plt
from Opencv1 import opencvcam


window = Tk()

window.title
window.geometry("1388x856")

origy = 80 # original x value
origx = 40 # original y value
increaseX = 65 # increase in x value
origX = 300
Swidth = 1388
Sheight = 856

breakfast = False
lunch= False

#operating hours

operation_message='Mon-Fri: 24hours \n Sat & Sun: 0600-0000'

homepagelogo = Image.open(r"homepage.png")
homepage = ImageTk.PhotoImage(homepagelogo)

#frames for 2nd page

macf = Frame(window, width = Swidth, height = Sheight)
subf = Frame(window, width = Swidth, height = Sheight)
sbf = Frame(window, width = Swidth, height = Sheight)
ljsf = Frame(window, width = Swidth, height = Sheight)
kfcf = Frame(window, width = Swidth, height = Sheight)
phf = Frame(window, width = Swidth, height = Sheight)

    #initialise image of storesf

mcdlogo = Image.open(r"mcdonalds.png")
subwaylogo = Image.open(r"subway.png")
sbuxlogo = Image.open(r"sbux.png")
longlogo = Image.open(r"long.png")
kfclogo = Image.open(r"kfc.png")
pizzalogo = Image.open(r"pizza.png")


    #for image of map
image = Image.open(r"mini project.jpg")
image = image.resize((650,450),Image.ANTIALIAS)
photo = ImageTk.PhotoImage(image)
label = Label(image = photo,bg='white')
label.image = photo
label.place(relx=0.5,rely=0.65, anchor = CENTER)

label1=Label(window, text ="Project : Food@NTU",
            fg="black",bg='white',font =("Weltron 2001",60)) \
            .place(relx = 0.5, rely = 0.1, anchor = CENTER)

#widget is always first argument in label
    

time1=''

clock=Label(window,font=('helevetica neue',50),fg="black",bg='white')
clock.place(relx = 0.5, rely = 0.22, anchor= CENTER)

def Time(): # TIME
    global time1
    global time2

    time2 = time.strftime('%H:%M:%S') # hour minute seconds

    if time2 != time1: 
        time1 = time2
        clock.config(text=time2)

    clock.after(200,Time)
    
day= Label(window,font=('helevetica neue',30),fg="black",bg='white')
day.place(relx=0.5,rely=0.3, anchor = CENTER)

def Date(): # DATE
    today = date.today()
    day1 = today.strftime("%d %B %Y")

    day.config(text=day1)

Time()
Date()

if '06' < time2[:2] < '12': # from 6am - 12pm
    i = 0
else:
    i =1

# buttons with logo of stalls & 2nd page after clicking logo

def raise_frame(frame):
    frame.tkraise()


for frame in (macf, subf, sbf, ljsf, kfcf, phf):
    frame.grid(row=0, column=0, sticky='news')

#for image of stalls in menu page
mcdlogo2 = Image.open(r"mcd2.png")
subwaylogo2 = Image.open(r"subway2.png")
sbuxlogo2 = Image.open(r"sbux2.jpg")
longlogo2 = Image.open(r"long2.png")
kfclogo2 = Image.open(r"kfc2.png")

#drop down menu for day

daylist = ['Monday,', 'Tuesday,', 'Wednesday,', 'Thursday,', 'Friday,', 'Saturday,', 'Sunday,']
menutlist = ['Breakfast(6am - 12pm)','Lunch(12pm-6am)']

    
def DAY(): # converting daynumber == days of the week 
    global dayofwk
    datetime.today()
    datetime(2012, 3, 23, 23, 24, 55, 173504)
    dayofwk = daylist[datetime.today().weekday()]

    
DAY()
selectday = StringVar(macf)
selectday.set(daylist[datetime.today().weekday()]) # default value


##################################### MCDONALDS ####################################

#main page button

mcd = ImageTk.PhotoImage(mcdlogo)
    
mcdb = Button(window, image = mcd, width="145",height="140",bg='white',
            command = lambda: raise_frame(macf)).place(x = 382.5, y =  308)

#menu page buttons

mcd2 = mcdlogo2.resize((280,180), Image.ANTIALIAS)
mcd2 = ImageTk.PhotoImage(mcd2) 

Label(macf, image = mcd2).place(x = 50,y = 30) #logo of mcdonalds

mac_quit_button = Button(macf, image = homepage,
                    command = lambda: macf.lower(),
                     bg = "white").place(relx = 0, rely = 0) #quit button

Label(macf,text = "Menu for", font=('happy day at school',160),\
      fg="black",bg='white').place(x = 460, y = 40) #"menu for" label

Label(macf,text = "Item", font=('royal acid',55),\
      fg="black",bg='white').place(x = 160, y = 300) #"item" label

Label(macf,text = "Price", font=('royal acid',55),\
      fg="black",bg='white').place(x = 550, y = 300) #"price" label

headingsize = 20


def macok(): 
    a = origX

    if mac_dayop.get() == 'Monday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 
        
            
            mcdmenu = {'Big Breakfast': '$8', 'Pancakes': '$5', 'Wrap': '$6', 'Breakfast Deluxe': '$7',\
                      'McMuffin': '$4'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)

                a += increaseX
            print('displayed mac  monday b menu')

        else:  #lunch
            genrt = Button(macf, text= "Generate real time", command = lambda: opencvcam(macf)).place(x = 1290, y = 200)
            mcdmenu = {'McChicken': '$2', 'Fries': '$3', 'Nuggets': '$4', 'Sundae': '$2',\
                      'Pie': '$1'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac lunch monday')
    if mac_dayop.get() == 'Tuesday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'McMuffin': '$4', 'Breakfast Deluxe': '$7', 'Platter': '$6', 'Burger': '$5',\
                      'Hashbrown': '$2'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac tues b')

        else:  #lunch
            mcdmenu = {'Big Mac': '$6', 'McSpicy': '$7', 'Nuggets': '$4', 'Sundae': '$2',\
                      'Fries': '$3'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac lunch tues')
    if mac_dayop.get() == 'Wednesday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Hashbrown': '$2', 'McMuffin': '$4', 'Pancakes': '$5', 'Coffee': '$2',\
                      'Big Breakfast': '$8'}

            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  wed break')


        else:  #lunch
            mcdmenu = {'Filet O Fish': '$4', 'McFlurry': '$2', 'Fries': '$3', 'Nuggets': '$4',\
                      'Pie': '$1'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  wed lunch')

    if mac_dayop.get() == 'Thursday,':

        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Coffee': '$2', 'Big Breakfast': '$8', 'Hashbrown': '$2', 'McMuffin': '$4',\
                      'Pancakes': '$5'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac thur break')

        else:  #lunch
            mcdmenu = {'Big Mac': '$6', 'Fries': '$3', 'Filet O Fish': '$4', 'Sundae': '$2',\
                      'McChicken': '$2'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac thurs lunch')

    if mac_dayop.get() == 'Friday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Pancakes': '$5', 'Burger': '$5', 'Big Breakfast': '$8', 'Breakfast Deluxe': '$7',\
                      'Coffee': '$2'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac fri break')

        else:  #lunch
            mcdmenu = {'McChicken': '$2', 'Sundae': '$2', 'Filet O Fish': '$4', 'Fries': '$3',\
                      'Big Mac': '$6'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac fri lunch')

    if mac_dayop.get() == 'Saturday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Breakfast Deluxe': '$7', 'Wrap': '$6', 'Coffee': '$2', 'Hashbrown': '$2',\
                      'Burger': '$5'}
        
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sat break')

        else:  #lunch
            mcdmenu = {'Nuggets': '$4', 'Pie': '$1', 'McChicken': '$2', 'Nuggets': '$4',\
                      'Fries': '$3'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  sat lunch')

    if mac_dayop.get() == 'Sunday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Coffee': '$2', 'Hashbrown': '$2', 'Wrap': '$6', 'Burger': '$5',\
                      'Big Breakfast': '$8'}
        
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sun break')

        else:  #lunch
            mcdmenu = { 'Fries': '$3', 'Filet O Fish': '$4', 'Pie': '$1', 'McChicken': '$2',\
                      'Nuggets': '$4'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sun lunch')

mac_timeop = StringVar(macf)
mac_timeop.set(menutlist[i]) # default value as today's time 
mac_timelist = OptionMenu(macf, mac_timeop, *menutlist)
mac_timelist.configure(font = ("royal acid", 45), width = 19, height = 1) 
mac_timelist.place(x = 630, y = 180)
daylist.append(dayofwk)
mac_dayop = StringVar(macf)
mac_dayop.set(daylist[-1]) #default value
mac_daylist = OptionMenu(macf, mac_dayop, *daylist[0:7])
mac_daylist.configure(font = ("royal acid", 45), width = 9, height = 1) 
mac_daylist.place(x = 380, y = 180)
macok()

macokb = Button(macf, text = 'Enter', command = macok).place(x = 600, y = 230)

 
def macdo_it():    #label and button appear once user clicks "Operating Hours" button
    macoplabel.place(relx = 0.77,rely=0.04)
    mac_quitop.place(relx = 0.912,rely=0.12)

mac_operation = Button(macf,text='Operating Hours', command = macdo_it).place(relx = 0.9, rely = 0)

def macquit_operatinghour():  #once user clicks on 'Close', the label and 'Close' button will disappear
    macoplabel.place_forget()
    mac_quitop.place_forget()
    
    
macoplabel = Label(macf, text = operation_message,bg='white', font = ("royal acid",30))  
mac_quitop = Button(macf, text ='Close',command = macquit_operatinghour)

#waiting time calculation

def waiting_time(): #to get user input
  
    mac_name = Label(macf, text = "Please input \n numbers only", bg ="#FFC300", font=("royal acidbath", 28), width = 15, height = 2)

    try:
        mac_user_input = int(macuserinput.get())
        mac_wait_for = str(mac_user_input*2)  #calculation for waiting time
        w = Label(macf, text ='Estimated waiting \n time: '+ mac_wait_for + ' mins     ', \
                  width = 15, height = 2,bg ="#FFC300", \
                  font=("royal acidbath", 28)).place(relx=0.68,rely=0.5)

    except:
        mac_name.place(relx=0.68,rely=0.5)
        


macalc = Button(macf, text ='Calculate', command = waiting_time,bg='white')
macalc.place(x=1220,y=380)   
macuserinput = Entry(macf, font = ("royal acid",28))
macuserinput.place(relx=0.75, rely=0.43, height = 35, width = 170)

Label(macf,text='Enter number of \n people in queue:',font=("royal acid", 28)).place(relx=0.6,rely=0.4)

#click once then appear. it will stay until user clicks again.
##################################### Subway ######################################################################


#main page button

sub = ImageTk.PhotoImage(subwaylogo)
subb = Button(window, image = sub, width="145",height="140",bg='white',
            command = lambda: raise_frame(subf)).place(x = 541, y =  308)

#menu page buttons

sub2 = subwaylogo2.resize((280,180), Image.ANTIALIAS)
sub2 = ImageTk.PhotoImage(sub2) 

Label(subf, image = sub2).place(x = 50,y = 30) #logo of mcdonalds


sub_quit_button = Button(subf, image = homepage,
                    command = lambda: subf.lower(),
                     bg = "white").place(relx = 0, rely = 0) #quit button

Label(subf,text = "Menu for", font=('happy day at school',160),\
      fg="black",bg='white').place(x = 460, y = 40) #"menu for" label

Label(subf,text = "Item", font=('royal acid',55),\
      fg="black",bg='white').place(x = 160, y = 300) #"item" label

Label(subf,text = "Price", font=('royal acid',55),\
      fg="black",bg='white').place(x = 550, y = 300) #"price" label

headingsize = 20


def subok(): 
    a = origX

    if sub_dayop.get() == 'Monday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Wrap': '$5', 'Subway Melt': '$2', 'Coffee': '$6', \
              'Salad': '$8', 'Cookie': '$2'}
        
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub monday b menu')

        else:  #lunch
            submenu = {'Egg Mayo': '$8', 'BLT': '$6', 'Roast Beef': '$7', \
              'Spicy Italian ': '$6'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub lunch monday')
    if sub_dayop.get() == 'Tuesday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Egg Mayo': '$8', 'Subway Melt': '$5', 'Roast Beef': '$7', \
              'Salad': '$6'}
        
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub tues b')

        else:  #lunch
            submenu = {'Teriyaki': '$7', 'Subway Melt': '$5', 'Spicy Italian': '$6', \
              'Turkey Ham': '$6.90'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub lunch tues')
    if sub_dayop.get() == 'Wednesday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Cold Cut Trio': '$7', 'Subway Melt': '$5', 'Tea': '$2', \
              'Cookie': '$2'}

            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub wed break')


        else:  #lunch
            submenu = {'BLT': '$7', 'Subway Melt': '$5', 'Steak': '$6', \
              'Egg Mayo': '$6.90'}
            
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub wed lunch')

    if sub_dayop.get() == 'Thursday,':

        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Tea': '$2', 'Subway Melt': '$5', 'Cheese': '$6', \
              'Salad': '$6'}
        
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub thur break')

        else:  #lunch
            submenu = {'Cold Cut Trio': '$7', 'Subway Melt': '$5', 'Steak & Cheese': '$6', \
              'Turkey Ham': '$6'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub thurs lunch')

    if sub_dayop.get() == 'Friday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Cold Cut Trio': '$7', 'Subway Melt': '$5', 'Steak & Cheese': '$6', \
              'Turkey Ham': '$6'}
        
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub fri break')

        else:  #lunch
            submenu = {'Egg Mayo': '$8', 'Subway Melt': '$5', 'Roast Beef': '$7', \
              'Salad': '$6'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub fri lunch')

    if sub_dayop.get() == 'Saturday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Egg Mayo': '$8', 'Subway Melt': '$5', 'Roast Beef': '$7', \
              'Salad': '$6'}
        
            for key, value in submenu.items():
                displaysub= Label(subf,\
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub sat break')

        else:  #lunch
            submenu = {'Cold Cut Trio': '$7', 'Subway Melt': '$5', 'Steak & Cheese': '$6', \
              'Turkey Ham': '$6'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub sat lunch')

    if sub_dayop.get() == 'Sunday,':
        
        if sub_timeop.get() == 'Breakfast(6am - 12pm)': 

            submenu = {'Egg Mayo': '$8', 'Subway Melt': '$5', 'Roast Beef': '$7', \
              'Salad': '$6'}
        
            for key, value in submenu.items():
                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub sun break')

        else:  #lunch
            submenu = {'Egg Mayo': '$8', 'Subway Melt': '$5.60', 'Roast Beef': '$7', \
              'Salad': '$6'}
            for key, value in submenu.items():

                displaysub= Label(subf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  sub sun lunch')

sub_timeop = StringVar(subf)
sub_timeop.set(menutlist[i]) # default value as today's time 
sub_timelist = OptionMenu(subf, sub_timeop, *menutlist)
sub_timelist.configure(font = ("royal acid", 45), width = 19, height = 1) 
sub_timelist.place(x = 630, y = 180)
sub_dayop = StringVar(subf)
sub_dayop.set(daylist[-1]) #default value
sub_daylist = OptionMenu(subf, sub_dayop, *daylist[0:7])
sub_daylist.configure(font = ("royal acid", 45), width = 9, height = 1) 
sub_daylist.place(x = 380, y = 180)
subok()
subokb = Button(subf, text = 'Enter', command = subok).place(x = 600, y = 230)

 
def subdo_it():    #label and button appear once user clicks "Operating Hours" button
    suboplabel.place(relx = 0.77,rely=0.04)
    sub_quitop.place(relx = 0.912,rely=0.12)

sub_operation = Button(subf,text='Operating Hours',
                    command = subdo_it).place(relx = 0.9, rely = 0)

def subquit_operatinghour():  #once user clicks on 'Close', the label and 'Close' button will disappear
    suboplabel.place_forget()
    sub_quitop.place_forget()
    
    
suboplabel = Label(subf, text = operation_message,bg='white', font = ("royal acid",30))  
sub_quitop = Button(subf, text ='Close',command = subquit_operatinghour)

#waiting time calculation

def waiting_time(): #to get user input
  
    name = Label(subf, text = "Please input \n numbers only", bg ="#FFC300", font=("royal acidbath", 28), width = 15, height = 2)

    try:
        user_input = int(userinput.get())
        wait_for = str(user_input*2)  #calculation for waiting time
        w = Label(subf, text ='Estimated waiting \n time: '+ wait_for + ' mins     ',\
                  width = 15, height = 2,bg ="#FFC300",\
                  font=("royal acidbath", 28)).place(relx=0.68,rely=0.5)

    except:
        name.place(relx=0.68,rely=0.5)
        


button = Button(subf, text ='Calculate', command = waiting_time,bg='white')
button.place(x=1220,y=380)   
userinput = Entry(subf, font = ("royal acid",28))
userinput.place(relx=0.75, rely=0.43, height = 35, width = 170)

Label(subf,text='Enter number of \n people in queue:',font=("royal acid", 28)).place(relx=0.6,rely=0.4)

#click once then appear. it will stay until user clicks again.
##################################### Starbucks ######################################################################


#main page button

star = ImageTk.PhotoImage(sbuxlogo)
starb = Button(window, image = star, width="145",height="140",bg='white',
            command = lambda: raise_frame(sbf)).place(x = 699, y =  308)

#menu page buttons

star2 = sbuxlogo2.resize((280,180), Image.ANTIALIAS)
star2 = ImageTk.PhotoImage(star2) 

Label(sbf, image = star2).place(x = 50,y = 30) #logo of mcdonalds


sbquit_button = Button(sbf, image = homepage,
                    command = lambda: sbf.lower(),
                     bg = "white").place(relx = 0, rely = 0) #quit button

Label(sbf,text = "Menu for", font=('happy day at school',160),\
      fg="black",bg='white').place(x = 460, y = 40) #"menu for" label

Label(sbf,text = "Item", font=('royal acid',55),\
      fg="black",bg='white').place(x = 160, y = 300) #"item" label

Label(sbf,text = "Price", font=('royal acid',55),\
      fg="black",bg='white').place(x = 550, y = 300) #"price" label

headingsize = 20


def sbok(): 
    a = origX

    if sb_dayop.get() == 'Monday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Sea Salt Caramel Cheesecake': '$4', 'Signature Chocolate Cake': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysub= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb monday b sub ')

        else:  #lunch
            sbmenu = {'Java Chip Frappuccino': '$7.50', 'Signature Chocolate Cake': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb lunch monday')
    if sb_dayop.get() == 'Tuesday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Java Chip Frappuccino': '$7.50', 'Signature Chocolate Cake': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb tues b')

        else:  #lunch
            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb lunch tues')
            
    if sb_dayop.get() == 'Wednesday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}

            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb wed break')


        else:  #lunch
            sbmenu = {'Country Chicken Pie': '$4', 'Signature Chocolate Cake': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            
            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb wed lunch')

    if sb_dayop.get() == 'Thursday,':

        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Country Chicken Pie': '$4', 'Signature Chocolate Cake': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb thur break')

        else:  #lunch
            sbmenu = {'Sea Salt Caramel Cheesecake': '$4', 'Signature Chocolate Cake': '$5.60', 'Ham and Cheese Brioche': '$5', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb thurs lunch')

    if sb_dayop.get() == 'Friday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Sea Salt Caramel Cheesecake': '$4', 'Signature Chocolate Cake': '$5.60', 'Ham and Cheese Brioche': '$5', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb fri break')

        else:  #lunch
            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb fri lunch')

    if sb_dayop.get() == 'Saturday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysb= Label(sbf,\
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb sat break')

        else:  #lunch
            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb sat lunch')

    if sb_dayop.get() == 'Sunday,':
        
        if sb_timeop.get() == 'Breakfast(6am - 12pm)': 

            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
        
            for key, value in sbmenu.items():
                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb sun break')

        else:  #lunch
            sbmenu = {'Strawberry Shortcake': '$4', 'Green Tea Creme Frappuccino': '$5.60', 'Caramel Frappucino': '$8.10', \
              'Brewed Coffee': '$3.80'}
            for key, value in sbmenu.items():

                displaysb= Label(sbf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed sb sun lunch')

sb_timeop = StringVar(sbf)
sb_timeop.set(menutlist[i]) # default value as today's time 
sb_timelist = OptionMenu(sbf, sb_timeop, *menutlist)
sb_timelist.configure(font = ("royal acid", 45), width = 19, height = 1) 
sb_timelist.place(x = 630, y = 180)
sb_dayop = StringVar(sbf)
sb_dayop.set(daylist[-1]) #default value
sb_daylist = OptionMenu(sbf, sb_dayop, *daylist[0:7])
sb_daylist.configure(font = ("royal acid", 45), width = 9, height = 1) 
sb_daylist.place(x = 380, y = 180)
sbok()
sbokb = Button(sbf, text = 'Enter', command = sbok).place(x = 600, y = 230)

#operating hours


 
def sbdo_it():    #label and button appear once user clicks "Operating Hours" button
    sboplabel.place(relx = 0.77,rely=0.04)
    sb_quitop.place(relx = 0.912,rely=0.12)

operation = Button(sbf,text='Operating Hours',
                    command = sbdo_it).place(relx = 0.9, rely = 0)

def sbquit_operatinghour():  #once user clicks on 'Close', the label and 'Close' button will disappear
    sboplabel.place_forget()
    sb_quitop.place_forget()
    
    
sboplabel = Label(sbf, text = operation_message,bg='white', font = ("royal acid",30))  
sb_quitop = Button(sbf, text ='Close',command = sbquit_operatinghour)

#waiting time calculation

def waiting_time(): #to get user input
  
    name = Label(sbf, text = "Please input \n numbers only", bg ="#FFC300",\
                 font=("royal acidbath", 28), width = 15, height = 2)

    try:
        user_input = int(userinput.get())
        wait_for = str(user_input*2)  #calculation for waiting time
        w = Label(sbf, text ='Estimated waiting \n time: '+ wait_for + ' mins     ',\
                  width = 15, height = 2,bg ="#FFC300",\
                  font=("royal acidbath", 28)).place(relx=0.68,rely=0.5)

    except:
        name.place(relx=0.68,rely=0.5)
        


button = Button(sbf, text ='Calculate', command = waiting_time,bg='white')
button.place(x=1220,y=380)   
userinput = Entry(sbf, font = ("royal acid",28))
userinput.place(relx=0.75, rely=0.43, height = 35, width = 170)

Label(sbf,text='Enter number of \n people in queue:', font=("royal acid", 28)).place(relx = 0.6,rely=0.4)

#click once then appear. it will stay until user clicks again.


window.mainloop()
# Out:
# displayed  mac fri lunch
# displayed  sub fri lunch
# displayed sb fri lunch
# displayed  mac lunch monday

# %%
search_list = list()
s = ""

def reset_list():
    if s != entry_widget_name.get():
        print(entry_widget_name.get())
        search_list.clear()
        text_widget_name.tag_remove(SEL, 1.0,"end-1c")

def search_words():
    reset_list()
    global search_list
    global s
    text_widget_name.focus_set()
    s = entry_widget_name.get()

    if s:
        if search_list == []:
            idx = "1.0"
        else:
            idx = search_list[-1]

        idx = text_widget_name.search(s, idx, nocase=1, stopindex=END)
        lastidx = '%s+%dc' % (idx, len(s))

        try:
            text_widget_name.tag_remove(SEL, 1.0,lastidx)
        except:
            pass

        try:
            text_widget_name.tag_add(SEL, idx, lastidx)
            counter_list = []
            counter_list = str(idx).split('.')      
            text_widget_name.mark_set("insert", "%d.%d" % (float(int(counter_list[0])), float(int(counter_list[1]))))
            text_widget_name.see(float(int(counter_list[0])))
            search_list.append(lastidx)
        except:
            MessageBox.showinfo("Search complete","No further matches")
            search_list.clear()
            text_widget_name.tag_remove(SEL, 1.0,"end-1c")

# %%
from tkinter import *
from PIL import Image, ImageTk  #for image of map
import time
from datetime import datetime, date
import numpy as np
import cv2
from matplotlib import pyplot as plt
import Opencv1


window = Tk()
window.title
window.geometry("1388x856")

origy = 80 # original x value
origx = 40 # original y value
increaseX = 65 # increase in x value
origX = 300

breakfast = False
lunch= False

#operating hours

operation_message='Mon-Fri: 24hours \n Sat & Sun: 0600-0000'

homepagelogo = Image.open(r"homepage.png")
homepage = ImageTk.PhotoImage(homepagelogo)

#frames for 2nd page

macf = Frame(window, width = 1388, height = 856)
subf = Frame(window, width = 1388, height = 856)
sbf = Frame(window, width = 1388, height = 856)
ljsf = Frame(window, width = 1388, height = 856)
kfcf = Frame(window, width = 1388, height = 856)
phf = Frame(window, width = 1388, height = 856)

    #initialise image of storesf

mcdlogo = Image.open(r"mcdonalds.png")
subwaylogo = Image.open(r"subway.png")
sbuxlogo = Image.open(r"sbux.png")
longlogo = Image.open(r"long.png")
kfclogo = Image.open(r"kfc.png")
pizzalogo = Image.open(r"pizza.png")


    #for image of map
image = Image.open(r"mini project.jpg")
image = image.resize((650,450),Image.ANTIALIAS)
photo = ImageTk.PhotoImage(image)
label = Label(image = photo,bg='white')
label.image = photo
label.place(relx=0.5,rely=0.65, anchor = CENTER)

label1=Label(window, text ="Project : Food@NTU",
            fg="black",bg='white',font =("Weltron 2001",60)) \
            .place(relx = 0.5, rely = 0.1, anchor = CENTER)

#widget is always first argument in label
    

time1=''

clock=Label(window,font=('helevetica neue',50),fg="black",bg='white')
clock.place(relx = 0.5, rely = 0.22, anchor= CENTER)

def Time(): # TIME
    global time1
    global time2

    time2 = time.strftime('%H:%M:%S') # hour minute seconds

    if time2 != time1: 
        time1 = time2
        clock.config(text=time2)

    clock.after(200,Time)
    
day= Label(window,font=('helevetica neue',30),fg="black",bg='white')
day.place(relx=0.5,rely=0.3, anchor = CENTER)

def Date(): # DATE
    today = date.today()
    day1 = today.strftime("%d %B %Y")

    day.config(text=day1)

Time()
Date()

if '06' < time2[:2] < '12': # from 6am - 12pm
    i = 0
else:
    i =1

# buttons with logo of stalls & 2nd page after clicking logo

def raise_frame(frame):
    frame.tkraise()


for frame in (macf, subf, sbf, ljsf, kfcf, phf):
    frame.grid(row=0, column=0, sticky='news')

#for image of stalls in menu page
mcdlogo2 = Image.open(r"mcd2.png")
subwaylogo2 = Image.open(r"subway2.png")
sbuxlogo2 = Image.open(r"sbux2.jpg")
longlogo2 = Image.open(r"long2.png")
kfclogo2 = Image.open(r"kfc2.png")

#drop down menu for day

daylist = ['Monday,', 'Tuesday,', 'Wednesday,', 'Thursday,', 'Friday,', 'Saturday,', 'Sunday,']
menutlist = ['Breakfast(6am - 12pm)','Lunch(12pm-6am)']

    
def DAY(): # converting daynumber == days of the week 
    global dayofwk
    datetime.today()
    datetime(2012, 3, 23, 23, 24, 55, 173504)
    dayofwk = daylist[datetime.today().weekday()]

    
DAY()
selectday = StringVar(macf)
selectday.set(daylist[datetime.today().weekday()]) # default value


##################################### MCDONALDS ####################################

#main page button

mcd = ImageTk.PhotoImage(mcdlogo)
    
mcdb = Button(window, image = mcd, width="145",height="140",bg='white',
            command = lambda: raise_frame(macf)).place(x = 382.5, y =  308)

#menu page buttons

mcd2 = mcdlogo2.resize((280,180), Image.ANTIALIAS)
mcd2 = ImageTk.PhotoImage(mcd2) 

Label(macf, image = mcd2).place(x = 50,y = 30) #logo of mcdonalds

mac_quit_button = Button(macf, image = homepage,
                    command = lambda: macf.lower(),
                     bg = "white").place(relx = 0, rely = 0) #quit button

Label(macf,text = "Menu for", font=('happy day at school',160),\
      fg="black",bg='white').place(x = 460, y = 40) #"menu for" label

Label(macf,text = "Item", font=('royal acid',55),\
      fg="black",bg='white').place(x = 160, y = 300) #"item" label

Label(macf,text = "Price", font=('royal acid',55),\
      fg="black",bg='white').place(x = 550, y = 300) #"price" label

headingsize = 20


def macok(): 
    a = origX

    if mac_dayop.get() == 'Monday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 
            e = Button(macf, text = 'real waiting time here', command= Opencv1.opencvcam(macf))
            
            mcdmenu = {'Big Breakfast': '$8', 'Pancakes': '$5', 'Wrap': '$6', 'Breakfast Deluxe': '$7',\
                      'McMuffin': '$4'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)

                a += increaseX
            print('displayed mac  monday b menu')

        else:  #lunch
            
            mcdmenu = {'McChicken': '$2', 'Fries': '$3', 'Nuggets': '$4', 'Sundae': '$2',\
                      'Pie': '$1'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac lunch monday')
    if mac_dayop.get() == 'Tuesday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'McMuffin': '$4', 'Breakfast Deluxe': '$7', 'Platter': '$6', 'Burger': '$5',\
                      'Hashbrown': '$2'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac tues b')

        else:  #lunch
            mcdmenu = {'Big Mac': '$6', 'McSpicy': '$7', 'Nuggets': '$4', 'Sundae': '$2',\
                      'Fries': '$3'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac lunch tues')
    if mac_dayop.get() == 'Wednesday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Hashbrown': '$2', 'McMuffin': '$4', 'Pancakes': '$5', 'Coffee': '$2',\
                      'Big Breakfast': '$8'}

            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  wed break')


        else:  #lunch
            mcdmenu = {'Filet O Fish': '$4', 'McFlurry': '$2', 'Fries': '$3', 'Nuggets': '$4',\
                      'Pie': '$1'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  wed lunch')

    if mac_dayop.get() == 'Thursday,':

        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Coffee': '$2', 'Big Breakfast': '$8', 'Hashbrown': '$2', 'McMuffin': '$4',\
                      'Pancakes': '$5'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac thur break')

        else:  #lunch
            mcdmenu = {'Big Mac': '$6', 'Fries': '$3', 'Filet O Fish': '$4', 'Sundae': '$2',\
                      'McChicken': '$2'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac thurs lunch')

    if mac_dayop.get() == 'Friday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Pancakes': '$5', 'Burger': '$5', 'Big Breakfast': '$8', 'Breakfast Deluxe': '$7',\
                      'Coffee': '$2'}
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac fri break')

        else:  #lunch
            mcdmenu = {'McChicken': '$2', 'Sundae': '$2', 'Filet O Fish': '$4', 'Fries': '$3',\
                      'Big Mac': '$6'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac fri lunch')

    if mac_dayop.get() == 'Saturday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Breakfast Deluxe': '$7', 'Wrap': '$6', 'Coffee': '$2', 'Hashbrown': '$2',\
                      'Burger': '$5'}
        
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sat break')

        else:  #lunch
            mcdmenu = {'Nuggets': '$4', 'Pie': '$1', 'McChicken': '$2', 'Nuggets': '$4',\
                      'Fries': '$3'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed mac  sat lunch')

    if mac_dayop.get() == 'Sunday,':
        
        if mac_timeop.get() == 'Breakfast(6am - 12pm)': 

            mcdmenu = {'Coffee': '$2', 'Hashbrown': '$2', 'Wrap': '$6', 'Burger': '$5',\
                      'Big Breakfast': '$8'}
        
            for key, value in mcdmenu.items():
                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sun break')

        else:  #lunch
            mcdmenu = { 'Fries': '$3', 'Filet O Fish': '$4', 'Pie': '$1', 'McChicken': '$2',\
                      'Nuggets': '$4'}
            for key, value in mcdmenu.items():

                displaymcd= Label(macf, \
                                  text= '{:<20} {:>10}'.format(key, value), width = 23, bg = "white",
                                  anchor = "e", font = ("royal acidbath", 45)).place(x = origx, y = origy+a)
                a += increaseX
            print('displayed  mac sun lunch')

mac_timeop = StringVar(macf)
mac_timeop.set(menutlist[i]) # default value as today's time 
mac_timelist = OptionMenu(macf, mac_timeop, *menutlist)
mac_timelist.configure(font = ("royal acid", 45), width = 19, height = 1) 
mac_timelist.place(x = 630, y = 180)
daylist.append(dayofwk)
mac_dayop = StringVar(macf)
mac_dayop.set(daylist[-1]) #default value
mac_daylist = OptionMenu(macf, mac_dayop, *daylist[0:7])
mac_daylist.configure(font = ("royal acid", 45), width = 9, height = 1) 
mac_daylist.place(x = 380, y = 180)
macok()

macokb = Button(macf, text = 'Enter', command = macok).place(x = 600, y = 230)

 
def macdo_it():    #label and button appear once user clicks "Operating Hours" button
    macoplabel.place(relx = 0.77,rely=0.04)
    mac_quitop.place(relx = 0.912,rely=0.12)

mac_operation = Button(macf,text='Operating Hours', command = macdo_it).place(relx = 0.9, rely = 0)

def macquit_operatinghour():  #once user clicks on 'Close', the label and 'Close' button will disappear
    macoplabel.place_forget()
    mac_quitop.place_forget()
    
    
macoplabel = Label(macf, text = operation_message,bg='white', font = ("royal acid",30))  
mac_quitop = Button(macf, text ='Close',command = macquit_operatinghour)

#waiting time calculation

def waiting_time(): #to get user input
  
    mac_name = Label(macf, text = "Please input \n numbers only", bg ="#FFC300", font=("royal acidbath", 28), width = 15, height = 2)

    try:
        mac_user_input = int(macuserinput.get())
        mac_wait_for = str(mac_user_input*2)  #calculation for waiting time
        w = Label(macf, text ='Estimated waiting \n time: '+ mac_wait_for + ' mins     ', \
                  width = 15, height = 2,bg ="#FFC300", \
                  font=("royal acidbath", 28)).place(relx=0.68,rely=0.5)

    except:
        mac_name.place(relx=0.68,rely=0.5)
        


macalc = Button(macf, text ='Calculate', command = waiting_time,bg='white')
macalc.place(x=1220,y=380)   
macuserinput = Entry(macf, font = ("royal acid",28))
macuserinput.place(relx=0.75, rely=0.43, height = 35, width = 170)

Label(macf,text='Enter number of \n people in queue:',font=("royal acid", 28)).place(relx=0.6,rely=0.4)


window.mainloop()
